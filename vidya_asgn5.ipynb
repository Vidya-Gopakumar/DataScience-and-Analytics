# %% [markdown]
# # importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# # reading data in python environment

# %%
txt_data=pd.read_csv('Add_sales_data_2018.csv')
txt_data.head()
# Out:
#          Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0  2018-10-08              208.00              222.25              206.85
# 1  2018-10-05              217.00              218.60              205.90
# 2  2018-10-04              223.50              227.80              216.15
# 3  2018-10-03              230.00              237.50              225.75
# 4  2018-10-01              234.55              234.60              221.05
#
#    Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 0              216.00              215.15              4093.065
# 1              210.25              209.20              4042.448
# 2              217.25              218.20              4213.819
# 3              226.45              227.60              4391.665
# 4              230.30              230.90              4350.683

# %%
txt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %% [markdown]
# # finding the relationship between profit and advertisement

# %%
import warnings
warnings.filterwarnings('ignore')
slice_dataa=txt_data[['Profit(in Thousands)','Add1(in Thousands)','Add2(in Thousands)','Add3(in Thousands)','Add4(in Thousands)','Add5(in Thousands)']]
sns.pairplot(slice_dataa,hue='Profit(in Thousands)')

# %% [markdown]
# # finding profit increases with advertisement

# %% [markdown]
# # finding the correlation using heatmap

# %%
corrmatrix=txt_data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,vmin=-.3,vmax=3,annot=True,linewidth=.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
part1=txt_data[["Profit(in Thousands)", "Add1(in Thousands)"]]
y = part1[["Profit(in Thousands)"]]

X = part1[["Add1(in Thousands)"]]
part1.head()
linr_model = LinearRegression().fit(X, y)

linr_model
# Out:
# LinearRegression()
